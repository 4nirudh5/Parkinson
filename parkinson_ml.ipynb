# %% [markdown]
# # **Libraries**

# %%
import pandas as pd
import numpy as np
from sklearn import metrics
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from imblearn.combine import SMOTEENN
import pickle
from imblearn.combine import SMOTEENN
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from matplotlib import pyplot

# %% [markdown]
# # **Data correction**

# %%
df = pd.read_csv('/content/parkinsonpp.csv')
df.head(20)
# Out:
#     Unnamed: 0  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0            0      119.992       157.302        74.997         0.00784
# 1            1      122.400       148.650       113.819         0.00968
# 2            2      116.682       131.111       111.555         0.01050
# 3            3      116.676       137.871       111.366         0.00997
# 4            4      116.014       141.781       110.655         0.01284
# 5            5      120.552       131.162       113.787         0.00968
# 6            6      120.267       137.244       114.820         0.00333
# 7            7      107.332       113.840       104.315         0.00290
# 8            8       95.730       132.068        91.754         0.00551
# 9            9       95.056       120.103        91.226         0.00532
# 10          10       88.333       112.240        84.072         0.00505
# 11          11       91.904       115.871        86.292         0.00540
# 12          12      136.926       159.866       131.276         0.00293
# 13          13      139.173       179.139        76.556         0.00390
# 14          14      152.845       163.305        75.836         0.00294
# 15          15      142.167       217.455        83.159         0.00369
# 16          16      144.188       349.259        82.764         0.00544
# 17          17      168.778       232.181        75.603         0.00718
# 18          18      153.046       175.829        68.623         0.00742
# 19          19      156.405       189.398       142.822         0.00768
#
#     MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0            0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1            0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2            0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3            0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4            0.00011   0.00655   0.00908     0.01966       0.06425  ...
# 5            0.00008   0.00463   0.00750     0.01388       0.04701  ...
# 6            0.00003   0.00155   0.00202     0.00466       0.01608  ...
# 7            0.00003   0.00144   0.00182     0.00431       0.01567  ...
# 8            0.00006   0.00293   0.00332     0.00880       0.02093  ...
# 9            0.00006   0.00268   0.00332     0.00803       0.02838  ...
# 10           0.00006   0.00254   0.00330     0.00763       0.02143  ...
# 11           0.00006   0.00281   0.00336     0.00844       0.02752  ...
# 12           0.00002   0.00118   0.00153     0.00355       0.01259  ...
# 13           0.00003   0.00165   0.00208     0.00496       0.01642  ...
# 14           0.00002   0.00121   0.00149     0.00364       0.01828  ...
# 15           0.00003   0.00157   0.00203     0.00471       0.01503  ...
# 16           0.00004   0.00211   0.00292     0.00632       0.02047  ...
# 17           0.00004   0.00284   0.00387     0.00853       0.03327  ...
# 18           0.00005   0.00364   0.00432     0.01092       0.05517  ...
# 19           0.00005   0.00372   0.00399     0.01116       0.03995  ...
#
#     Shimmer:DDA      NHR     HNR  status      RPDE       DFA   spread1  \
# 0       0.06545  0.02211  21.033       1  0.414783  0.815285 -4.813031
# 1       0.09403  0.01929  19.085       1  0.458359  0.819521 -4.075192
# 2       0.08270  0.01309  20.651       1  0.429895  0.825288 -4.443179
# 3       0.08771  0.01353  20.644       1  0.434969  0.819235 -4.117501
# 4       0.10470  0.01767  19.649       1  0.417356  0.823484 -3.747787
# 5       0.06985  0.01222  21.378       1  0.415564  0.825069 -4.242867
# 6       0.02337  0.00607  24.886       1  0.596040  0.764112 -5.634322
# 7       0.02487  0.00344  26.892       1  0.637420  0.763262 -6.167603
# 8       0.03218  0.01070  21.812       1  0.615551  0.773587 -5.498678
# 9       0.04324  0.01022  21.862       1  0.547037  0.798463 -5.011879
# 10      0.03237  0.01166  21.118       1  0.611137  0.776156 -5.249770
# 11      0.04272  0.01141  21.414       1  0.583390  0.792520 -4.960234
# 12      0.01968  0.00581  25.703       1  0.460600  0.646846 -6.547148
# 13      0.02184  0.01041  24.889       1  0.430166  0.665833 -5.660217
# 14      0.03191  0.00609  24.922       1  0.474791  0.654027 -6.105098
# 15      0.02316  0.00839  25.175       1  0.565924  0.658245 -5.340115
# 16      0.02908  0.01859  22.333       1  0.567380  0.644692 -5.440040
# 17      0.04322  0.02919  20.376       1  0.631099  0.605417 -2.931070
# 18      0.07413  0.03160  17.280       1  0.665318  0.719467 -3.949079
# 19      0.05164  0.03365  17.153       1  0.649554  0.686080 -4.554466
#
#      spread2        D2       PPE
# 0   0.266482  2.301442  0.284654
# 1   0.335590  2.486855  0.368674
# 2   0.311173  2.342259  0.332634
# 3   0.334147  2.405554  0.368975
# 4   0.234513  2.332180  0.410335
# 5   0.299111  2.187560  0.357775
# 6   0.257682  1.854785  0.211756
# 7   0.183721  2.064693  0.163755
# 8   0.327769  2.322511  0.231571
# 9   0.325996  2.432792  0.271362
# 10  0.391002  2.407313  0.249740
# 11  0.363566  2.642476  0.275931
# 12  0.152813  2.041277  0.138512
# 13  0.254989  2.519422  0.199889
# 14  0.203653  2.125618  0.170100
# 15  0.210185  2.205546  0.234589
# 16  0.239764  2.264501  0.218164
# 17  0.434326  3.007463  0.430788
# 18  0.357870  3.109010  0.377429
# 19  0.340176  2.856676  0.322111
#
# [20 rows x 24 columns]

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df


df = swap_columns(df, 'Unnamed: 0', 'status')

# %%
df
# Out:
#      status  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0         1      119.992       157.302        74.997         0.00784
# 1         1      122.400       148.650       113.819         0.00968
# 2         1      116.682       131.111       111.555         0.01050
# 3         1      116.676       137.871       111.366         0.00997
# 4         1      116.014       141.781       110.655         0.01284
# ..      ...          ...           ...           ...             ...
# 190       0      174.188       230.978        94.261         0.00459
# 191       0      209.516       253.017        89.488         0.00564
# 192       0      174.688       240.005        74.287         0.01360
# 193       0      198.764       396.961        74.904         0.00740
# 194       0      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1             0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2             0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3             0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4             0.00011   0.00655   0.00908     0.01966       0.06425  ...
# ..                ...       ...       ...         ...           ...  ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      Shimmer:DDA      NHR     HNR  Unnamed: 0      RPDE       DFA   spread1  \
# 0        0.06545  0.02211  21.033           0  0.414783  0.815285 -4.813031
# 1        0.09403  0.01929  19.085           1  0.458359  0.819521 -4.075192
# 2        0.08270  0.01309  20.651           2  0.429895  0.825288 -4.443179
# 3        0.08771  0.01353  20.644           3  0.434969  0.819235 -4.117501
# 4        0.10470  0.01767  19.649           4  0.417356  0.823484 -3.747787
# ..           ...      ...     ...         ...       ...       ...       ...
# 190      0.07008  0.02764  19.517         190  0.448439  0.657899 -6.538586
# 191      0.04812  0.01810  19.147         191  0.431674  0.683244 -6.195325
# 192      0.03804  0.10715  17.883         192  0.407567  0.655683 -6.787197
# 193      0.03794  0.07223  19.020         193  0.451221  0.643956 -6.744577
# 194      0.03078  0.04398  21.209         194  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 0    0.266482  2.301442  0.284654
# 1    0.335590  2.486855  0.368674
# 2    0.311173  2.342259  0.332634
# 3    0.334147  2.405554  0.368975
# 4    0.234513  2.332180  0.410335
# ..        ...       ...       ...
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [195 rows x 24 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)
df
# Out:
#      status  MDVP:Fo(Hz)  MDVP:Fhi(Hz)  MDVP:Flo(Hz)  MDVP:Jitter(%)  \
# 0         1      119.992       157.302        74.997         0.00784
# 1         1      122.400       148.650       113.819         0.00968
# 2         1      116.682       131.111       111.555         0.01050
# 3         1      116.676       137.871       111.366         0.00997
# 4         1      116.014       141.781       110.655         0.01284
# ..      ...          ...           ...           ...             ...
# 190       0      174.188       230.978        94.261         0.00459
# 191       0      209.516       253.017        89.488         0.00564
# 192       0      174.688       240.005        74.287         0.01360
# 193       0      198.764       396.961        74.904         0.00740
# 194       0      214.289       260.277        77.973         0.00567
#
#      MDVP:Jitter(Abs)  MDVP:RAP  MDVP:PPQ  Jitter:DDP  MDVP:Shimmer  ...  \
# 0             0.00007   0.00370   0.00554     0.01109       0.04374  ...
# 1             0.00008   0.00465   0.00696     0.01394       0.06134  ...
# 2             0.00009   0.00544   0.00781     0.01633       0.05233  ...
# 3             0.00009   0.00502   0.00698     0.01505       0.05492  ...
# 4             0.00011   0.00655   0.00908     0.01966       0.06425  ...
# ..                ...       ...       ...         ...           ...  ...
# 190           0.00003   0.00263   0.00259     0.00790       0.04087  ...
# 191           0.00003   0.00331   0.00292     0.00994       0.02751  ...
# 192           0.00008   0.00624   0.00564     0.01873       0.02308  ...
# 193           0.00004   0.00370   0.00390     0.01109       0.02296  ...
# 194           0.00003   0.00295   0.00317     0.00885       0.01884  ...
#
#      MDVP:APQ  Shimmer:DDA      NHR     HNR      RPDE       DFA   spread1  \
# 0     0.02971      0.06545  0.02211  21.033  0.414783  0.815285 -4.813031
# 1     0.04368      0.09403  0.01929  19.085  0.458359  0.819521 -4.075192
# 2     0.03590      0.08270  0.01309  20.651  0.429895  0.825288 -4.443179
# 3     0.03772      0.08771  0.01353  20.644  0.434969  0.819235 -4.117501
# 4     0.04465      0.10470  0.01767  19.649  0.417356  0.823484 -3.747787
# ..        ...          ...      ...     ...       ...       ...       ...
# 190   0.02745      0.07008  0.02764  19.517  0.448439  0.657899 -6.538586
# 191   0.01879      0.04812  0.01810  19.147  0.431674  0.683244 -6.195325
# 192   0.01667      0.03804  0.10715  17.883  0.407567  0.655683 -6.787197
# 193   0.01588      0.03794  0.07223  19.020  0.451221  0.643956 -6.744577
# 194   0.01373      0.03078  0.04398  21.209  0.462803  0.664357 -5.724056
#
#       spread2        D2       PPE
# 0    0.266482  2.301442  0.284654
# 1    0.335590  2.486855  0.368674
# 2    0.311173  2.342259  0.332634
# 3    0.334147  2.405554  0.368975
# 4    0.234513  2.332180  0.410335
# ..        ...       ...       ...
# 190  0.121952  2.657476  0.133050
# 191  0.129303  2.784312  0.168895
# 192  0.158453  2.679772  0.131728
# 193  0.207454  2.138608  0.123306
# 194  0.190667  2.555477  0.148569
#
# [195 rows x 23 columns]

# %% [markdown]
# # **Create variables**

# %%
df.columns
# Out:
# Index(['status', 'MDVP:Fo(Hz)', 'MDVP:Fhi(Hz)', 'MDVP:Flo(Hz)',
#        'MDVP:Jitter(%)', 'MDVP:Jitter(Abs)', 'MDVP:RAP', 'MDVP:PPQ',
#        'Jitter:DDP', 'MDVP:Shimmer', 'MDVP:Shimmer(dB)', 'Shimmer:APQ3',
#        'Shimmer:APQ5', 'MDVP:APQ', 'Shimmer:DDA', 'NHR', 'HNR', 'RPDE', 'DFA',
#        'spread1', 'spread2', 'D2', 'PPE'],
#       dtype='object')

# %%
x = df.iloc[:,1:23]
y = df.iloc[:,[0]]

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2)

# %%
x.shape
# Out:
# (195, 22)

# %%
y.shape
# Out:
# (195, 1)

# %% [markdown]
# # **Model**

# %% [markdown]
# ## Decision Tree

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train,y_train)
y_pred = dt.predict(x_test)

# %%
score = metrics.accuracy_score(y_test,y_pred)
print(score*100)
# Out:
# 84.61538461538461

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

xr_train,xr_test,yr_train,yr_test=train_test_split(x_resampled, y_resampled,test_size=0.2)

dts = DecisionTreeClassifier()
dts.fit(xr_train,yr_train)
yr_pred = dts.predict(xr_test)

# %%
dts.score(xr_test,yr_test)
# Out:
# 0.9777777777777777

# %%
filename = 'decisiontree_sm.sav'
pickle.dump(dts, open(filename, 'wb'))

# %% [markdown]
# ## Random Forest

# %%
rf = RandomForestClassifier()
rf.fit(x_train,y_train)
y_pred = rf.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().

# %%
rf.score(x_test,y_test)
# Out:
# 0.9230769230769231

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

xf_train,xf_test,yf_train,yf_test=train_test_split(x_resampled, y_resampled,test_size=0.2)

rfs = RandomForestClassifier()
rfs.fit(xf_train,yf_train)
yf_pred = rfs.predict(xf_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   import sys

# %%
rfs.score(xf_test,yf_test)
# Out:
# 0.9534883720930233

# %%
filename = 'randomforest_sm.sav'
pickle.dump(rfs, open(filename, 'wb'))

# %% [markdown]
# ## Naive Bayes

# %%
nb = GaussianNB()
nb.fit(x_train,y_train)
y_pred = nb.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
nb.score(x_test,y_test)
# Out:
# 0.717948717948718

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

xb_train,xb_test,yb_train,yb_test=train_test_split(x_resampled, y_resampled,test_size=0.2)

nbs = DecisionTreeClassifier()
nbs.fit(xb_train,yb_train)
yb_pred = nbs.predict(xb_test)

# %%
nbs.score(xb_test,yb_test)
# Out:
# 0.9777777777777777

# %%
print(classification_report(yb_test,yb_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        24
#            1       1.00      1.00      1.00        21
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
filename = 'naive_sm.sav'
pickle.dump(nbs, open(filename, 'wb'))

# %% [markdown]
# ## K-nearest Negibour

# %%
knn = KNeighborsClassifier()
knn.fit(x_train,y_train)
y_pred = knn.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
knn.score(x_test,y_test)
# Out:
# 0.8974358974358975

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

xn_train,xn_test,yn_train,yn_test=train_test_split(x_resampled, y_resampled,test_size=0.2)

knns = KNeighborsClassifier()
knns.fit(xn_train,yn_train)
yn_pred = knns.predict(xn_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/neighbors/_classification.py:198: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)

# %%
knns.score(xn_test,yn_test)
# Out:
# 1.0

# %%
mae_knns = metrics.mean_absolute_error(yn_test, yn_pred)
mse_knns = metrics.mean_squared_error(yn_test, yn_pred)
print(mae_knns, mse_knns)
# Out:
# 0.0 0.0

# %%
print(classification_report(yn_test,yn_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        27
#            1       1.00      1.00      1.00        18
#
#     accuracy                           1.00        45
#    macro avg       1.00      1.00      1.00        45
# weighted avg       1.00      1.00      1.00        45

# %%
filename = 'knn_sm.sav'
pickle.dump(knns, open(filename, 'wb'))

# %% [markdown]
# ## SVM

# %%
svm = SVC()
svm.fit(x_train,y_train)
y_pred = svm.predict(x_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svm.score(x_test,y_test)
# Out:
# 0.8205128205128205

# %%
sm = SMOTEENN()
x_resampled, y_resampled = sm.fit_resample(x,y)

xm_train,xm_test,ym_train,ym_test=train_test_split(x_resampled, y_resampled,test_size=0.2)

svms = SVC()
svms.fit(xm_train,ym_train)
ym_pred = svms.predict(xm_test)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
svms.score(xm_test,ym_test)
# Out:
# 0.7872340425531915
